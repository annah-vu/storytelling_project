# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
custdetails = pd.read_csv('custdetails.csv')
custdetails
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  \
# 0     1371-DWPAZ  Female                  0     Yes        Yes
# 1     2520-SGTTA  Female                  0     Yes        Yes
# 2     2775-SEFEE    Male                  0      No        Yes
# 3     2923-ARZLG    Male                  0     Yes        Yes
# 4     3115-CZMZD    Male                  0      No        Yes
# ...          ...     ...                ...     ...        ...
# 7038  3910-MRQOY  Female                  0     Yes        Yes
# 7039  6010-DDPPW    Male                  0     Yes         No
# 7040  7083-MIOPC  Female                  1     Yes         No
# 7041  8207-VVMYB  Female                  0     Yes        Yes
# 7042  5893-KCLGT  Female                  0     Yes         No
#
#       partner_dependents  phone_service  internet_service  contract_type  \
# 0                      3              0                 1              2
# ...

# %%
custdetails_df = custdetails[(custdetails['contract_type'] == 0)]

custdetails_df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  \
# 11    0021-IKXGC  Female                  1      No         No
# 12    0023-HGHWL    Male                  1      No         No
# 13    0032-PGELS  Female                  0     Yes        Yes
# 14    0082-LDZUE    Male                  0      No         No
# 15    0107-WESLM    Male                  0      No         No
# ...          ...     ...                ...     ...        ...
# 6768  3173-WSSUE  Female                  1     Yes         No
# 6773  3486-HOOGQ  Female                  0     Yes         No
# 6784  4656-CAURT    Male                  1     Yes         No
# 6803  5668-MEISB  Female                  1     Yes        Yes
# 6807  5965-GGPRW    Male                  0     Yes        Yes
#
#       partner_dependents  phone_service  internet_service  contract_type  \
# 11                     0              2                 2              0
# ...
